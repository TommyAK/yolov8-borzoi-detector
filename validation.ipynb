# %%
from ultralytics import YOLO

# %%
# assigning best trained model
model = YOLO("C:\\Users\\Tommy\\Documents\\yolo\\borzoi classifier\\runs\\detect\\train\\weights\\best.pt")

# %%
# begin validation
model.val(data="C:\\Users\\Tommy\\Documents\\yolo\\borzoi classifier\\data\\data.yaml")
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.9 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 8192MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\Tommy\Documents\yolo\borzoi classifier\data\val\labels.cache... 52 images, 0 backgrounds, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:09<00:00,  2.47s/it]
#                    all         52         55      0.982      0.999      0.994      0.863
# Speed: 3.7ms preprocess, 7.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs\detect\val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001C70726FEB0>
# ...
